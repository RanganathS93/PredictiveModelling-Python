# %% [markdown]
# ## Ranganath Shankar Rao - ranganath.shankar@gmail.com - BHG Assessment

# %%
# importing required libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
plt.rcParams['figure.figsize'] = [8,5]
plt.rcParams['font.size'] =14
plt.rcParams['font.weight']= 'bold'
plt.style.use('seaborn-whitegrid')

# %%
df_bhg = pd.read_csv("Model Test Data.csv")
print("Sample data")
print('\nNumber of rows and columns in the data set: ',df_bhg.shape)
df_bhg.head()
# Out:
# Sample data
#
# Number of rows and columns in the data set:  (10000, 11)
#            y         var_1        var_2        var_3     var_4         var_5  \
# 0  58.891377   5285.076955  8102.610429 -142802.4627  0.731818  61045.686450
# 1  57.641838   2094.137183  7432.119245 -147434.0657  2.527586  48485.220290
# 2  53.746536   5830.245294  6613.941822 -129496.5961  2.625691  36301.747910
# 3  36.168986  13039.246420  5270.829420 -439972.8126  0.844833  -5909.877785
# 4  32.669772   4611.755026  3456.822275 -138594.7123  4.058533  37602.705370
#
#          var_6        var_7        var_8        var_9  var_10
# 0  183502.7911  2418498.392  27880.60083  360626.7592       4
# 1  232809.7287  1779351.332  32153.75776  382670.3624       5
# 2  214837.0432  2072100.771  30642.70182  370120.6062       2
# 3  173613.1204  1899841.158  41311.52728  329891.8986       4
# 4  228498.4096  1925463.972  27522.27266  473752.7977       3

# %% [markdown]
# ## Exploratory Data Analysis

# %%
## Check for missing values
plt.figure(figsize=(12,4))
sns.heatmap(df_bhg.isnull(),cbar=False,cmap='viridis',yticklabels=False)
plt.title('Missing value in the dataset');

# %% [markdown]
# #### There is no missing value in the dataset.

# %%
df_bhg.describe()
# Out:
#                   y         var_1         var_2          var_3         var_4  \
# count  10000.000000  10000.000000  10000.000000   10000.000000  10000.000000
# mean      12.190351   8445.963010   3450.252510  168505.815510      1.610510
# std       16.020137   3540.407793   2544.552718  154606.758685      0.799212
# min      -20.486397  -5583.153749  -6338.250221 -439972.812600     -1.328607
# 25%        0.342919   6012.666381   1689.792306   64840.482335      1.070263
# 50%       10.881019   8463.373285   3430.595021  167029.781400      1.598712
# 75%       23.047831  10864.843605   5165.408836  272343.174250      2.146489
# max       94.749833  23299.976630  12288.699000  857156.728100      4.639956
#
#                var_5          var_6         var_7         var_8  \
# count   10000.000000   10000.000000  1.000000e+04  10000.000000
# mean    73390.402240   85873.402570  1.150636e+06  22190.066240
# std     42488.751840   71600.020020  8.840513e+05   9835.270071
# ...

# %% [markdown]
# ## Distribution of all the features and target variable

# %%
f= plt.figure(figsize=(12,4))

ax=f.add_subplot(121)
sns.distplot(df_bhg['y'],bins=50,color='r',ax=ax)
ax.set_title('Distribution of target variable y')

f= plt.figure(figsize=(12,4))

ax=f.add_subplot(121)
sns.distplot(df_bhg['var_1'],bins=50,color='r',ax=ax)
ax.set_title('Distribution of variable var_1')

f= plt.figure(figsize=(12,4))

ax=f.add_subplot(121)
sns.distplot(df_bhg['var_2'],bins=50,color='r',ax=ax)
ax.set_title('Distribution of variable var_2')

f= plt.figure(figsize=(12,4))

ax=f.add_subplot(121)
sns.distplot(df_bhg['var_3'],bins=50,color='r',ax=ax)
ax.set_title('Distribution of variable var_3')

f= plt.figure(figsize=(12,4))

ax=f.add_subplot(121)
sns.distplot(df_bhg['var_4'],bins=50,color='r',ax=ax)
ax.set_title('Distribution of variable var_4')

f= plt.figure(figsize=(12,4))

ax=f.add_subplot(121)
sns.distplot(df_bhg['var_5'],bins=50,color='r',ax=ax)
ax.set_title('Distribution of variable var_5')

f= plt.figure(figsize=(12,4))

ax=f.add_subplot(121)
sns.distplot(df_bhg['var_6'],bins=50,color='r',ax=ax)
ax.set_title('Distribution of variable var_6')

f= plt.figure(figsize=(12,4))

ax=f.add_subplot(121)
sns.distplot(df_bhg['var_7'],bins=50,color='r',ax=ax)
ax.set_title('Distribution of variable var_7')

f= plt.figure(figsize=(12,4))

ax=f.add_subplot(121)
sns.distplot(df_bhg['var_8'],bins=50,color='r',ax=ax)
ax.set_title('Distribution of variable var_8')

f= plt.figure(figsize=(12,4))

ax=f.add_subplot(121)
sns.distplot(df_bhg['var_9'],bins=50,color='r',ax=ax)
ax.set_title('Distribution of variable var_9')

f= plt.figure(figsize=(12,4))

ax=f.add_subplot(121)
sns.distplot(df_bhg['var_10'],bins=50,color='r',ax=ax)
ax.set_title('Distribution of variable var_10')
# Out:
# C:\Users\Ranganath ShankarRao\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Ranganath ShankarRao\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
## Box Plot of Target and Features
plt.figure(figsize=(14,6))
sns.boxplot(data=df_bhg,palette='rainbow')
plt.title('Box plot of target and features');

# %% [markdown]
# ### From the above distribution plot and box plots we can say that data is normally distributed, have very less skew and contains few outliers.

# %%
## Scatter plot of var_2
sns.scatterplot(data=df_bhg, x="var_2", y="y");

# %%
## Scatter plot of var_3
sns.scatterplot(data=df_bhg, x="var_3", y="y");

# %% [markdown]
# ## Data analysis and Feature Selection

# %%
## Plot the correlation matrix heatmap
figure = plt.figure(figsize=(12, 6))
sns.heatmap(df_bhg.corr(), annot=True,cmap=plt.cm.cool)
plt.tight_layout()
plt.xlabel('Corr')
plt.show()

# %%
# Correlation between Features and target Values
df_bhg.corr()['y']
# Out:
# y         1.000000
# var_1    -0.336184
# var_2     0.497815
# var_3    -0.596058
# var_4    -0.045849
# var_5    -0.401891
# var_6     0.429807
# var_7     0.029095
# var_8     0.194788
# var_9     0.379986
# var_10   -0.052502
# Name: y, dtype: float64

# %%
# Features and Target Plot
FCT = pd.DataFrame(df_bhg.corr()['y'])
FCT.drop('y', inplace=True)
FCT.sort_values(['y'], ascending=False, inplace=True)
FCT_x = FCT.index
FCT_y = FCT['y']
sns.barplot(x=FCT_y,y=CRR_x).set_title('Correlation between Features and target', size='20')
# Out:
# Text(0.5, 1.0, 'Correlation between Features and target')

# %% [markdown]
# ### From the above Heatmap,Corr-values and the plots we can say that variables Var_2,Var_6, Var_9, Var_8 and Var_7 have positive correlation with the target y. Variables Var_4,Var_10,Var_1,Var_5,Var_3 have negative correlation with y.

# %% [markdown]
# ### We can infer that variables 7, 4, 10 can be excluded as features as they are least correlated features.

# %%
# dropping least correlated features
df_bhg2 = df_bhg.drop(columns=['var_7', 'var_4', 'var_10'])
df_bhg2.head()
# Out:
#            y         var_1        var_2        var_3         var_5  \
# 0  58.891377   5285.076955  8102.610429 -142802.4627  61045.686450
# 1  57.641838   2094.137183  7432.119245 -147434.0657  48485.220290
# 2  53.746536   5830.245294  6613.941822 -129496.5961  36301.747910
# 3  36.168986  13039.246420  5270.829420 -439972.8126  -5909.877785
# 4  32.669772   4611.755026  3456.822275 -138594.7123  37602.705370
#
#          var_6        var_8        var_9
# 0  183502.7911  27880.60083  360626.7592
# 1  232809.7287  32153.75776  382670.3624
# 2  214837.0432  30642.70182  370120.6062
# 3  173613.1204  41311.52728  329891.8986
# 4  228498.4096  27522.27266  473752.7977

# %% [markdown]
# ## Creating new Correlation matrix and Selecting the Upper triangular matrix

# %%
Co_matrx = df_bhg2.corr().abs()
Co_matrx
# Out:
#               y     var_1     var_2     var_3     var_5     var_6     var_8  \
# y      1.000000  0.336184  0.497815  0.596058  0.401891  0.429807  0.194788
# var_1  0.336184  1.000000  0.135317  0.196789  0.191826  0.169298  0.212547
# var_2  0.497815  0.135317  1.000000  0.033808  0.035389  0.602046  0.208451
# var_3  0.596058  0.196789  0.033808  1.000000  0.808120  0.040761  0.283731
# var_5  0.401891  0.191826  0.035389  0.808120  1.000000  0.277714  0.413344
# var_6  0.429807  0.169298  0.602046  0.040761  0.277714  1.000000  0.103821
# var_8  0.194788  0.212547  0.208451  0.283731  0.413344  0.103821  1.000000
# var_9  0.379986  0.342938  0.370873  0.409241  0.054084  0.097726  0.146210
#
#           var_9
# y      0.379986
# var_1  0.342938
# var_2  0.370873
# var_3  0.409241
# var_5  0.054084
# var_6  0.097726
# var_8  0.146210
# var_9  1.000000

# %%
Up_tri = Co_matrx.where(np.triu(np.ones(Co_matrx.shape),k=1).astype(bool))
Up_tri
# Out:
#         y     var_1     var_2     var_3     var_5     var_6     var_8  \
# y     NaN  0.336184  0.497815  0.596058  0.401891  0.429807  0.194788
# var_1 NaN       NaN  0.135317  0.196789  0.191826  0.169298  0.212547
# var_2 NaN       NaN       NaN  0.033808  0.035389  0.602046  0.208451
# var_3 NaN       NaN       NaN       NaN  0.808120  0.040761  0.283731
# var_5 NaN       NaN       NaN       NaN       NaN  0.277714  0.413344
# var_6 NaN       NaN       NaN       NaN       NaN       NaN  0.103821
# var_8 NaN       NaN       NaN       NaN       NaN       NaN       NaN
# var_9 NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           var_9
# y      0.379986
# var_1  0.342938
# var_2  0.370873
# var_3  0.409241
# var_5  0.054084
# var_6  0.097726
# var_8  0.146210
# var_9       NaN

# %% [markdown]
# ### Dropping the columns with high Correlation - selecting columns having correlation greater than 0.80

# %%
to_drop = [column for column in Up_tri.columns if any(Up_tri[column] > 0.80)]
print(); print(to_drop)
# Out:
# ['var_5']

# %% [markdown]
# ### Final Data set

# %%
df_final = df_bhg2.drop(columns = 'var_5')
df_final.head()
# Out:
#            y         var_1        var_2        var_3        var_6  \
# 0  58.891377   5285.076955  8102.610429 -142802.4627  183502.7911
# 1  57.641838   2094.137183  7432.119245 -147434.0657  232809.7287
# 2  53.746536   5830.245294  6613.941822 -129496.5961  214837.0432
# 3  36.168986  13039.246420  5270.829420 -439972.8126  173613.1204
# 4  32.669772   4611.755026  3456.822275 -138594.7123  228498.4096
#
#          var_8        var_9
# 0  27880.60083  360626.7592
# 1  32153.75776  382670.3624
# 2  30642.70182  370120.6062
# 3  41311.52728  329891.8986
# 4  27522.27266  473752.7977

# %% [markdown]
# ## Prediction Model

# %%
# defining feature matrix(X) and response vector(y)
target = df_final['y']
features = df_final.drop(columns=['y'] , axis ='columns')

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.25,random_state=42)

print("Features length:", len(features))
print("X_train length:", len(X_train))
print("X_test length:", len(X_test))
# Out:
# Features length: 10000
# X_train length: 7500
# X_test length: 2500

# %% [markdown]
# ## Linear Regression Model

# %%
from sklearn import metrics
from sklearn.model_selection import cross_val_score

#cross validation
def cross_val(model):
    pred = cross_val_score(model, features, target, cv=10)
    return pred.mean()

# evaluating using MAE, MSE, RMSE and R2 Square
def print_evaluate(true, predicted):  
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    print('MAE:', mae)
    print('MSE:', mse)
    print('RMSE:', rmse)
    print('R2 Square', r2_square)
    print('__________________________________')
    
def evaluate(true, predicted):
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    return mae, mse, rmse, r2_square

# %%
# create linear regression object
from sklearn import linear_model, metrics
reg = linear_model.LinearRegression()

# train the model using the training sets
reg.fit(X_train, y_train)

# regression Intercept and coefficients
print('Coefficients: ', reg.coef_)
print('Intercept: ', reg.intercept_)
# Out:
# Coefficients:  [ 1.13631685e-05  4.34818873e-03 -4.51207098e-05 -2.77623208e-06
#  -1.68321550e-06  8.66426532e-05]
# Intercept:  -8.307975805066263

# %%
pred = reg.predict(X_test)

test_pred = reg.predict(X_test)
train_pred = reg.predict(X_train)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test, test_pred)
print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)
# Out:
# Test set evaluation:
# _____________________________________
# MAE: 5.882986465303891
# MSE: 56.86692456129368
# RMSE: 7.541016149120335
# R2 Square 0.7740307646712598
# __________________________________
# Train set evaluation:
# _____________________________________
# MAE: 5.936480920057874
# MSE: 59.6363187333728
# RMSE: 7.7224554860078545
# R2 Square 0.7690670815444204
# __________________________________

# %%
# create a dataframe to store all the model details
result_df = pd.DataFrame(data=[["Linear Regression", *evaluate(y_test, test_pred) , cross_val(linear_model.LinearRegression())]], 
                          columns=['Model', 'MAE', 'MSE', 'RMSE', 'R2 Square', "Cross Validation"])
result_df
# Out:
#                Model       MAE        MSE      RMSE  R2 Square  \
# 0  Linear Regression  5.882986  56.866925  7.541016   0.774031
#
#    Cross Validation
# 0         -0.014279

# %% [markdown]
# #### The R2 Score IS 0.774 and RMSE value is 7.54

# %%
# variance score: 1 means perfect prediction
print('Variance score: {}'.format(reg.score(X_test, y_test)))
# Out:
# Variance score: 0.7740307646712598

# %%
# Check for Linearity
f = plt.figure(figsize=(14,5))
ax = f.add_subplot(121)
sns.scatterplot(y_test,test_pred,ax=ax,color='r')
ax.set_title('Check for Linearity:\n Actual Vs Predicted value')

# Check for Residual normality & mean
ax = f.add_subplot(122)
sns.distplot((y_test - test_pred),ax=ax,color='b')
ax.axvline((y_test - test_pred).mean(),color='k',linestyle='--')
ax.set_title('Check for Residual normality & mean: \n Residual eror');
# Out:
# C:\Users\Ranganath ShankarRao\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ranganath ShankarRao\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Check for Multivariate Normality
# Quantile-Quantile plot 
f,ax = plt.subplots(1,2,figsize=(14,6))
import scipy as sp
_,(_,_,r)= sp.stats.probplot((y_test - test_pred),fit=True,plot=ax[0])
ax[0].set_title('Check for Multivariate Normality: \nQ-Q Plot')

#Check for Homoscedasticity
sns.scatterplot(y = (y_test - test_pred ), x= y_pred_sk, ax = ax[1],color='r') 
ax[1].set_title('Check for Homoscedasticity: \nResidual Vs Predicted');

# %%
R_square_sk = reg.score(X_test,y_test)
# Check for Multicollinearity
#Variance Inflation Factor
VIF = 1/(1- R_square_sk)
VIF
# Out:
# 4.425381174323129

# %% [markdown]
# ## The model assumption Linear regression is a follows:
# ### 1. In our model the actual vs predicted plot is curve so linear assumption fails.
# ### 2. The residual mean is zero hence residuals are not normally distributed.
# ### 3. Q-Q plot shows as value log value greater than 1.5 trends to increase
# ### 4. The plot is exhibit heteroscedastic, error will insease after certian point.
# ### 5. The Variance Inflation Factor is less than 5, so data is moderately correlated.
# ### 6. The RMSE value is low but the R2 value or variance score can be improved.

# %% [markdown]
# ## Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_reg = PolynomialFeatures(degree=3)

X_train_poly = poly_reg.fit_transform(X_train)
X_test_poly = poly_reg.transform(X_test)

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

lin_reg = make_pipeline(StandardScaler(with_mean=False), linear_model.LinearRegression())

lin_reg.fit(X_train_poly,y_train)

test_pred1 = lin_reg.predict(X_test_poly)
train_pred1 = lin_reg.predict(X_train_poly)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test, test_pred)
print('====================================')
print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)
# Out:
# Test set evaluation:
# _____________________________________
# MAE: 3.3883062027240665
# MSE: 20.15009301757508
# RMSE: 4.4888854983809825
# R2 Square 0.9199305897740843
# __________________________________
# ...
# Train set evaluation:
# _____________________________________
# MAE: 3.3136443730511234
# MSE: 17.30102479456632
# RMSE: 4.159450059150407
# R2 Square 0.9330043129264163
# __________________________________

# %% [markdown]
# #### The R2 Score IS 0.9199 and RMSE value is 4.48

# %%
# Check for Linearity
f = plt.figure(figsize=(14,5))
ax = f.add_subplot(121)
sns.scatterplot(y_test,test_pred1,ax=ax,color='r')
ax.set_title('Check for Linearity:\n Actual Vs Predicted value')

# Check for Residual normality & mean
ax = f.add_subplot(122)
sns.distplot((y_test - test_pred1),ax=ax,color='b')
ax.axvline((y_test - test_pred).mean(),color='k',linestyle='--')
ax.set_title('Check for Residual normality & mean: \n Residual eror');
# Out:
# C:\Users\Ranganath ShankarRao\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Ranganath ShankarRao\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Check for Multivariate Normality
# Quantile-Quantile plot 
f,ax = plt.subplots(1,2,figsize=(14,6))
import scipy as sp
_,(_,_,r)= sp.stats.probplot((y_test - test_pred1),fit=True,plot=ax[0])
ax[0].set_title('Check for Multivariate Normality: \nQ-Q Plot')

#Check for Homoscedasticity
sns.scatterplot(y = (y_test - test_pred1 ), x= y_pred_sk, ax = ax[1],color='r') 
ax[1].set_title('Check for Homoscedasticity: \nResidual Vs Predicted');

# %%
R2 = 0.9199
# Check for Multicollinearity
#Variance Inflation Factor
VIF = 1/(1- R2)
VIF
# Out:
# 12.484394506866424

# %% [markdown]
# ## The model assumption Polynomial regression with degree 3 is a follows:
# ### 1. In our model the actual vs predicted plot is following a linear path.
# ### 2. The residual error is normally distributed.
# ### 3. Q-Q plot shows evidence of normal distribution.
# ### 4. The plot is exhibiting homoscedasticity i.e.the variance of the residual is symmetrically distributed across the residual line.
# ### 5. The Variance Inflation Factor is greater than 5, so data is highly correlated.
# ### 6. The model has a low RMSE value and high R2 or variance score which indicates model's goodness of fit is very high.
